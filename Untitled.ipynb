# %%
LS23=(-1)^5*L[3,2]+(-1)^3*L[2]*L[3]+L[2,3];
LS15=(-1)^6*L[5,1]+(-1)^5*L[1]*L[5]+L[1,5];
LS6=(-1)^6*L[6]+L[6];

# %%
Expand[LS23*LS15]
# Out:
# L[1] L[2] L[3] L[5] - L[2] L[3] L[1, 5] - L[1] L[5] L[2, 3] + L[1, 5] L[2, 3] +
#
# >   L[1] L[5] L[3, 2] - L[1, 5] L[3, 2] - L[2] L[3] L[5, 1] + L[2, 3] L[5, 1] -
#
# >   L[3, 2] L[5, 1]

# %%
Expand[LS6*LS23]
# Out:
# -2 L[2] L[3] L[6] + 2 L[6] L[2, 3] - 2 L[6] L[3, 2]

# %%
f[x_,y_]:=
x*y*(x^2-y^2)/(x^2+y^2)

# %%
fx[x_,y_]=Simplify[D[f[x,y],x]]
fy[x_,y_]=Simplify[D[f[x,y],y]]
fxy[x_,y_]=Simplify[D[fx[x,y],y]]
fyx[x_,y_]=Simplify[D[fy[x,y],x]]
# Out:
#     4      2  2    4
# y (x  + 4 x  y  - y )
# ---------------------
#        2    2 2
#      (x  + y )
#  5      3  2      4
# x  - 4 x  y  - x y
# -------------------
#       2    2 2
#     (x  + y )
#  6      4  2      2  4    6
# x  + 9 x  y  - 9 x  y  - y
# ---------------------------
#           2    2 3
#         (x  + y )
#  6      4  2      2  4    6
# x  + 9 x  y  - 9 x  y  - y
# ---------------------------
#           2    2 3
#         (x  + y )

# %%
Simplify[D[fx[0,y],y]]
# Out:
# -1

# %%
fx[0,y]
# Out:
# -y

# %%
fy[x,0]
# Out:
# x

# %%
Plot3D[f[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
Plot3D[fx[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
Plot3D[fy[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
Plot3D[fyx[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
Simplify[fxy[t,a*t]]
# Out:
#        2      4    6
# 1 + 9 a  - 9 a  - a
# --------------------
#            2 3
#      (1 + a )

# %%
Plot3D[x*y/(x^2+y^2),{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
Li12[t_]:=Sum[Sum[t^{m1}/(m1*m2^2),{m1,1,m2-1}],{m2,2,Infinity}];
Li3[t_]:=Sum[t^n/(n^3),{n,1,Infinity}];

# %%
Chk[t_]:=Simplify[Li12[t]-Li3[t]]

# %%
Chk[1]
Chk[t]
# Out:
# {0}
#                          m2
#                         t   LerchPhi[t, 1, m2] + Log[1 - t]
# {-PolyLog[3, t] + Sum[-(-----------------------------------), {m2, 2, Infinity}]}
#                                           2
#                                         m2

# %%
Li12[1]
# Out:
# {Zeta[3]}

# %%
Plot3D[Log[1+x]*Log[1+y],{x,-1,1},{y,-1,1}]
Plot3D[(x+y)^3,{x,-1,1},{y,-1,1}]
Plot3D[Tan[x*y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-
# -Graphics3D-
# -Graphics3D-

# %%
F[x_,y_]:=Log[1+x]*Log[1+y];
G[x_,y_]:=(x+y)^3;
H[x_,y_]:=Tan[x*y];

# %%
Fdx[x_,y_]=D[F[x,y],{x,1}]
Gdx[x_,y_]=D[G[x,y],{x,1}]
Hdx[x_,y_]=D[H[x,y],{x,1}]
Hdy[x_,y_]=D[H[x,y],{y,1}]
# Out:
# Log[1 + y]
# ----------
#   1 + x
#          2
# 3 (x + y)
#           2
# y Sec[x y]
#           2
# x Sec[x y]

# %%
Fdx[0,0]
Gdx[0,0]
Hdx[0,0]
Hdy[0,0]
# Out:
# 0
# 0
# 0
# 0

# %%
Fa[x_,y_]:=x+y+x*y
Plot3D[Fa[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
Series[Fa[x,y],{x,0,2},{y,0,2}]
# Out:
#          3                 3          3
# (y + O[y] ) + (1 + y + O[y] ) x + O[x]

# %%
Fb[x_,y_]:=Exp[x*y]
Plot3D[Fb[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
D[Fb[x,y],{x,1},{y,1}]
# Out:
#  x y    x y
# E    + E    x y

# %%
Fc[x_,y_]:=Sin[x*y]
Plot3D[Fc[x,y],{x,-1,1},{y,-1,1}]
# Out:
# -Graphics3D-

# %%
A[x_,y_]=Fc[x,y]+D[Fc[x,y],{x,1}]+D[Fc[x,y],{y,1}]+1/2*(s^2*D[Fc[x,y],{x,2}]+2*s*t*D[Fc[x,y],{x,1},{y,1}]+t^2*D[Fc[x,y],{y,2}])
# Out:
# x Cos[x y] + y Cos[x y] + Sin[x y] +
#
#        2  2              2  2
#     -(t  x  Sin[x y]) - s  y  Sin[x y] + 2 s t (Cos[x y] - x y Sin[x y])
# >   --------------------------------------------------------------------
#                                      2

# %%
A[0,0]
# Out:
# s t

# %%
Solve[x^2+3*x+1==0,x]
# Out:
#        -3 - Sqrt[5]         -3 + Sqrt[5]
# {{x -> ------------}, {x -> ------------}}
#             2                    2

# %%
Reduce[-(a-3)^2/2-a+7>0,a]
# Out:
# -1 < a < 5

# %%
Sum[t^k,{k,1,p-1}]
# Out:
#       p
# -t + t
# -------
# -1 + t

# %%
# Out:
# Global`Tex
