# %%
MZV[k_]:=Zeta[k];

MZSV2[k1_,k2_]:=
Sum[
    Sum[
        1/(m1^{k1}*(m1+m2)^{k2}),
        {m2,0,Infinity}
    ],
    {m1,1,Infinity}
];

MZSV3[k1_,k2_,k3_]:=
Sum[Sum[Sum[1/(m1^{k1}*(m1+m2)^{k2}*(m1+m2+m3)^{k3}),{m3,0,Infinity}],{m2,1,Infinity}],{m1,1,infinity}];

# %%
MZSV2[1,2]+MZV[3]+MZSV3[1,2,2]
# Out:
#                                            4
# {3 Zeta[3] + (DifferenceRoot[{-(#2 (1 + #2)  #1[#2]) +
#
#                                           2        3       4
# >             (1 + #2) (17 + 37 #2 + 33 #2  + 15 #2  + 3 #2 ) #1[1 + #2] +
#
#                                     2        3        4       5
# >             (-49 - 133 #2 - 146 #2  - 82 #2  - 24 #2  - 3 #2 ) #1[2 + #2] +
#
#                                                                      4
#                       5                                            Pi
# >             (2 + #2)  #1[3 + #2] == 0, #1[1] == 0, #1[2] == -6 + ---,
#                                                                    15
#
#                                                 4
#                                               Pi
#                             4   -6 + 16 (-6 + ---)
#                           Pi                  15
# >           #1[3] == -6 + --- + ------------------} & ][1 + infinity] +
# ...

# %%
N[MZSV3[1,1,2]]

# %%
l
