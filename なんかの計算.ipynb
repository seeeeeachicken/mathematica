# %%
xz[i_]=Apart[1/((i-x+z)*(i-x-z))]
xyz[i_]=Apart[1/((i-x)*(i-y)-z^2)]
# Out:
#           1                       1
# --------------------- - ----------------------
# 2 (i - x) (i - x + z)   2 (i - x) (-i + x + z)
#               1
# -(--------------------------)
#     2                      2
#   -i  + i x + i y - x y + z

# %%
Product[xz[i],{i,p,n}]
Product[xyz[i],{i,p,n}]
# Out:
#                                 1
# -----------------------------------------------------------------
# Pochhammer[p - x - z, 1 + n - p] Pochhammer[p - x + z, 1 + n - p]
#                                    2            2      2
#                     -x - y - Sqrt[x  - 2 x y + y  + 4 z ]
# 1 / (Pochhammer[p + -------------------------------------, 1 + n - p]
#                                       2
#
#                                     2            2      2
#                      -x - y + Sqrt[x  - 2 x y + y  + 4 z ]
# >     Pochhammer[p + -------------------------------------, 1 + n - p])
#                                        2

# %%
Sum[Product[xyz[i],{i,p,n}],{n,p,Infinity}]
# Out:
#                                                   2            2      2
#                                     x   y   Sqrt[x  - 2 x y + y  + 4 z ]
# (-4 HypergeometricPFQ[{1}, {1 + p - - - - - ----------------------------,
#                                     2   2                2
#
#                               2            2      2
#                 x   y   Sqrt[x  - 2 x y + y  + 4 z ]
# >       1 + p - - - - + ----------------------------}, 1]) /
#                 2   2                2
#
#                           2            2      2
# >   ((2 p - x - y + Sqrt[x  - 2 x y + y  + 4 z ])
#
#                             2            2      2
# >     (-2 p + x + y + Sqrt[x  - 2 x y + y  + 4 z ]))

# %%
??HypergeometricPFQ
# Out:
# HypergeometricPFQ[{a , …, a }, {b , …, b }, z]
#                     1      p     1      q
#
# >    is the generalized hypergeometric function    F  (a ; b ; z).
#                                                  p    q
#
#
# Attributes[HypergeometricPFQ]={NumericFunction, Protected, ReadProtected}

# %%
Product[1/(1-a+k),{k,0,n}]
# Out:
#                 1
# -(-----------------------------)
#   (-1 + a) Pochhammer[2 - a, n]

# %%
# Out:
# Set::write: Tag Plus in b + (x + y) is Protected.
# Set::write: Tag Times in b (x + y) is Protected.
# Solve::ivar: x + y is not a valid variable.
#                      2
# Solve[{x + y, x y - z }, {x + y, b}]

# %%
Simplify[Log[1+(p+1)*t]+Log[1+(p-1-x)*t]]
# Out:
# Log[1 + t + p t] + Log[1 + t (-1 + p - x)]

# %%
A=(1+(p+1)*t)*(1+(p-1-x)*t)*(1-a*t)*(1-b*t)
B=(1-x*t)*(1-(p-a)*t)*(1-(p-b)*t)
# Out:
# (1 - a t) (1 - b t) (1 + (1 + p) t) (1 + t (-1 + p - x))
# (1 - (-a + p) t) (1 - (-b + p) t) (1 - t x)

# %%
Expand[A]/Expand[B]
# Out:
#                           2        2          2          2    2  2      3      3
# (1 - a t - b t + 2 p t - t  + a b t  - 2 a p t  - 2 b p t  + p  t  + a t  + b t  +
#
#                3      2  3      2  3        4        2  4          2        2
# >     2 a b p t  - a p  t  - b p  t  - a b t  + a b p  t  - t x - t  x + a t  x +
#
#          2        2        3        3          3          3          3          4
# >     b t  x - p t  x + a t  x + b t  x - a b t  x + a p t  x + b p t  x - a b t  x -
#
#              4
# >     a b p t  x) /
#
#                                   2        2        2    2  2            2        2
# >   (1 + a t + b t - 2 p t + a b t  - a p t  - b p t  + p  t  - t x - a t  x - b t  x +
#
#            2          3          3          3      2  3
# >     2 p t  x - a b t  x + a p t  x + b p t  x - p  t  x)

# %%
Collect[Expand[A],t]
# Out:
#                             2                              2
# 1 + t (-a - b + 2 p - x) + t  (-1 + a b - 2 a p - 2 b p + p  - x + a x + b x - p x) +
#
#      3                       2      2
# >   t  (a + b + 2 a b p - a p  - b p  + a x + b x - a b x + a p x + b p x) +
#
#      4                2
# >   t  (-(a b) + a b p  - a b x - a b p x)

# %%
TeXForm[x/5]

# %%
Sum[t^mr,{mr,m(r-1)-1,p-1}]

# %%
A=Collect[Expand[(1 - x*t)*(1 + (n - 1 + \[Alpha] - x)*t)* (1 + (n - 1 + \[Beta] - x)*t)],t]
# Out:
#                                   2
# 1 + t (-2 + 2 n - 3 x + α + β) + t
#
#                  2                    2
# >    (1 - 2 n + n  + 4 x - 4 n x + 3 x  - α + n α - 2 x α - β + n β - 2 x β + α β) +
#
#      3                2        2        2    3                  2
# >   t  (-x + 2 n x - n  x - 2 x  + 2 n x  - x  + x α - n x α + x  α + x β - n x β +
#
#         2
# >      x  β - x α β)

# %%
B=Collect[Expand[ (1+(n-1)*t)(1+(n-1-x)*t)*(1+(\[Alpha]-x)t)*(1+(\[Beta]-x)*t)],t]
# Out:
#                                   2
# 1 + t (-2 + 2 n - 3 x + α + β) + t
#
#                  2                    2
# >    (1 - 2 n + n  + 5 x - 5 n x + 3 x  - 2 α + 2 n α - 2 x α - 2 β + 2 n β - 2 x β +
#
#                3                    2        2        2    3                2
# >      α β) + t  (-2 x + 4 n x - 2 n  x - 4 x  + 4 n x  - x  + α - 2 n α + n  α +
#
#                           2                  2                        2
# >      3 x α - 3 n x α + x  α + β - 2 n β + n  β + 3 x β - 3 n x β + x  β - 2 α β +
#
#                            4   2        2    2  2    3      3                    2
# >      2 n α β - x α β) + t  (x  - 2 n x  + n  x  + x  - n x  - x α + 2 n x α - n  x α -
#
#         2        2                      2        2        2                      2
# >      x  α + n x  α - x β + 2 n x β - n  x β - x  β + n x  β + α β - 2 n α β + n  α β +
#
# >      x α β - n x α β)

# %%
Simplify[\[Alpha]+\[Beta],{\[Alpha]+\[Beta]==x+y,\[Alpha]*\[Beta]==z^2}]
# Out:
# α + β

# %%
Simplify[Expand[(1 - x*t)*(1 + (n - 1 + \[Alpha] - x)*t)* (1 + (n - 1 + \[Beta] - x)*t)],{\[Alpha]+\[Beta]==x+y,\[Alpha]*\[Beta]==z^2}]
# Out:
# -((-1 + t x) (-1 - t (-1 + n + y - α)) (-1 - t (-1 + n + y - β)))

# %%
Simplify[
Coefficient[
Collect[
Expand[
(1 - x*t)*(1 + (n - 1 + \[Alpha] - x)*t)* (1 + (n - 1 + \[Beta] - x)*t)
],t]
,t^2]
# Out:
#            2                    2
# 1 - 2 n + n  + 4 x - 4 n x + 3 x  - α + n α - 2 x α - β + n β - 2 x β + α β

# %%
Kill[A,B]
# Out:
# Kill[1 + t (-2 + 2 n - 3 x + α + β) +
#
#       2             2                    2
# >    t  (1 - 2 n + n  + 4 x - 4 n x + 3 x  - α + n α - 2 x α - β + n β - 2 x β + α β) +
#
#       3                2        2        2    3                  2
# >    t  (-x + 2 n x - n  x - 2 x  + 2 n x  - x  + x α - n x α + x  α + x β - n x β +
#
#          2
# >       x  β - x α β), 1 + t (-2 + 2 n - 3 x + α + β) +
#
#       2             2                    2
# >    t  (1 - 2 n + n  + 5 x - 5 n x + 3 x  - 2 α + 2 n α - 2 x α - 2 β + 2 n β - 2 x β +
#
#                 3                    2        2        2    3                2
# >       α β) + t  (-2 x + 4 n x - 2 n  x - 4 x  + 4 n x  - x  + α - 2 n α + n  α +
#
#                            2                  2                        2
# >       3 x α - 3 n x α + x  α + β - 2 n β + n  β + 3 x β - 3 n x β + x  β - 2 α β +
#
#                             4   2        2    2  2    3      3
# ...

# %%
A=(1 - xt)*(1 + (n - 1 + \[Alpha] - x)*t) *(1 + (n - 1 + \[Beta] - x)*t)
B= (1+(n-1)*t)*(1+(n-1-x)*t)*(1+(\[Alpha]-x)*t)*(1+(\[Beta]-x)*t)
# Out:
# (1 - xt) (1 + t (-1 + n - x + α)) (1 + t (-1 + n - x + β))
# (1 + (-1 + n) t) (1 + t (-1 + n - x)) (1 + t (-x + α)) (1 + t (-x + β))

# %%
Apart[A/B]
# Out:
#        (-1 + xt) (1 - t + n t - t x + t α)
# -------------------------------------------------- +
# (1 - t + n t) (1 - t + n t - t x) (-1 + t x - t α)
#
#                 2        2    2  2    2        2                      2           2
# >   (t - n t - t  + 2 n t  - n  t  - t  x + n t  x - t xt + n t xt + t  xt - 2 n t  xt +
#
#         2  2       2           2         2        2      2           2
# >      n  t  xt + t  x xt - n t  x xt + t  α - n t  α - t  xt α + n t  xt α) /
#
# >    ((1 - t + n t) (1 - t + n t - t x) (-1 + t x - t α) (1 - t x + t β))

# %%
Pochhammer[a-x,n+p]
# Out:
# Pochhammer[a - x, n + p]

# %%
Mod[HypergeometricPFQ[{1-x,1+p,1-p}, {2-a, 2-b}, 1],p]
# Out:
# Mod[HypergeometricPFQ[{1 - p, 1 + p, 1 - x}, {2 - a, 2 - b}, 1], p]

# %%
A1=1-x
A2=1+p
A3=1-p
B1=2-a
B2=2-b
# Out:
# 1 - x
# 1 + p
# 1 - p
# 2 - a
# 2 - b

# %%
B1+B2-A1-A2
# Out:
# 2 - a - b - p + x

# %%
B2-A3
# Out:
# 1 - b + p

# %%
B1-A2
# Out:
# 1 - a - p

# %%
p[n_]=Product[i-x-y,{i,1,n}]
Kill[p[n_]]
# Out:
# Pochhammer[1 - x - y, n]
# Kill[Pochhammer[1 - x - y, n_]]

# %%
Expand[p[2],x-y]
# Out:
# (1 - x - y) (2 - x - y)

# %%
p[3]
# Out:
# (1 - x - y) (2 - x - y) (3 - x - y)

# %%
p[p_,l_]=Product[z+i,{i,1,p-l}]
# Out:
# Pochhammer[1 + z, -l + p]

# %%
p[5,2]/Pochhammer[z-2+1,1]
# Out:
# (1 + z) (2 + z) (3 + z)
# -----------------------
#         -1 + z

# %%
(z^4-1)/(z-1)
# Out:
#       4
# -1 + z
# -------
# -1 + z

# %%
afo[n_]=Expand[Product[z^2-i^2,{i,1,n}]]
# Out:
#     n
# (-1)  Pochhammer[1 - z, n] Pochhammer[1 + z, n]

# %%
Expand[afo[3]]
# Out:
#           2       4    6
# -36 + 49 z  - 14 z  + z

# %%
affo[p_]=(Pochhammer[1-x,p-1]*Pochhammer[1,p-1])/(Pochhammer[2-\[Alpha],p-1]*Pochhammer[2-\[Beta],p-1])
# Out:
#   Pochhammer[1, -1 + p] Pochhammer[1 - x, -1 + p]
# ---------------------------------------------------
# Pochhammer[2 - α, -1 + p] Pochhammer[2 - β, -1 + p]

# %%
affo[5]
# Out:
#               24 (1 - x) (2 - x) (3 - x) (4 - x)
# ---------------------------------------------------------------
# (2 - α) (3 - α) (4 - α) (5 - α) (2 - β) (3 - β) (4 - β) (5 - β)

# %%
Solve[{12*ab+5*ac+13==0,13*ab+5*bc+12==0,13*ac+12*bc+5==0},{ab, bc,ac}]
# Out:
#           12                    5
# {{ab -> -(--), bc -> 0, ac -> -(--)}}
#           13                    13
