# %%
f[x_]:=x*Sqrt[1+x]

# %%
Together[f'[x]]
Together[f''[x]]
Together[f'''[x]]
Together[f''''[x]]
Together[f'''''[x]]
# Out:
#    2 + 3 x
# -------------
# 2 Sqrt[1 + x]
#   4 + 3 x
# ------------
#          3/2
# 4 (1 + x)
#  -3 (2 + x)
# ------------
#          5/2
# 8 (1 + x)
#  3 (8 + 3 x)
# -------------
#           7/2
# 16 (1 + x)
# -15 (10 + 3 x)
# --------------
#           9/2
# 32 (1 + x)

# %%
Together[%]
# Out:
# -15 (10 + 3 x)
# --------------
#           9/2
# 32 (1 + x)

# %%
Integrate[Integrate[1/t1,{t1,t2,1}]/(t2-1),{t2,0,1}]
# Out:
#    2
# -Pi
# ----
#  6

# %%
SetAttributes[e, Constant]

# %%
Integrate[1/(t1-1)*1/t2,{t1,e,t2},{t2,e,1-e}]
# Out:
#                                1
# ConditionalExpression[Log[-1 + -] (-Log[-1 + e] + Log[-1 + t2]),
#                                e
#
# >   ((Im[e] >= 0 && Im[t2] >= 0) ||
#
#             Im[e] (-1 + Re[t2])
# >      (1 + ------------------- <= Re[e] &&
#                   Im[t2]
#
# >        ((Im[e] >= Im[t2] && Im[e] (-1 + Re[t2]) >= Im[t2] (-1 + Re[e])) ||
#
# >          (Im[e] <= Im[t2] && Im[e] (-1 + Re[t2]) <= Im[t2] (-1 + Re[e])))) ||
#
# >      (Im[e] <= 0 && Im[t2] <= 0)) &&
#
#            1 - e           1 - e                  -1 + e             -1 + e
# >    (((Re[------] < -1 || ------ ∉ Reals) && (Re[------] == 0 || Re[------] >= 1)) ||
#            e - t2          e - t2                 e - t2             e - t2
#
#            1 - e               -1 + e         1 - e               -1 + e
# >      (Re[------] >= 0 && (Re[------] < 0 || ------ ∉ Reals)) || ------ ∉ Reals)]
#            e - t2              e - t2         e - t2              e - t2

# %%
Integrate[-Log[t]/(t-1),t]
Integrate[Log[1-t]/(t),t]
# Out:
# PolyLog[2, 1 - t]
# -PolyLog[2, t]

# %%
Integrate[Integrate[t1,{t1,0,t2}]*(t2+1),{t2,0,1}]
Integrate[t1,{t1,0,1}]*Integrate[2-t2,{t2,0,1}]
Integrate[Integrate[(1-t1),{t1,0,t2}]*(2-t2),{t2,0,1}]
# Out:
# 7
# --
# 24
# 3
# -
# 4
# 11
# --
# 24

# %%
SetAttributes[X,Constant]
Integrate[1/(t2*(t1-1)),{t1,X,1},{t2,1,t1}]
# Out:
# ConditionalExpression[PolyLog[2, 1 - X], 0 < Re[X] < 1 && Im[X] == 0]
