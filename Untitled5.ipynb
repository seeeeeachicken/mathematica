# %%
TeXForm[Simplify[Sum[t^mr,{mr,m(r-1)-1,p-1}]]]
# Out:
# \frac{t^{p+1}-t^{m (r-1)}}{(t-1) t}

# %%
TeXForm[Collect[Expand[(1-t)*(1-x)-y*t],t]]
# Out:
# t (x-y-1)-x+1

# %%
a[0]:=0; a[n_]:=-((x-n+1)*(y+n-1)-z^2)/(n*(n-x))*a[n-1]+1

# %%
Table[a[n], {n, 0, 10}]
# Out:
#                                2
#            (-1 + x) (1 + y) - z
# {0, 1, 1 - ---------------------, 1 -
#                  2 (2 - x)
#
#                                                        2
#                            2       (-1 + x) (1 + y) - z
# >    (((-2 + x) (2 + y) - z ) (1 - ---------------------)) / (3 (3 - x)),
#                                          2 (2 - x)
#
#                               2
# >   1 - (((-3 + x) (3 + y) - z ) (1 -
#
#                                                             2
#                                 2       (-1 + x) (1 + y) - z
# >         (((-2 + x) (2 + y) - z ) (1 - ---------------------)) / (3 (3 - x)))) /
#                                               2 (2 - x)
#
#                                              2
# >     (4 (4 - x)), 1 - (((-4 + x) (4 + y) - z )
#
#                                    2
# >       (1 - (((-3 + x) (3 + y) - z )
#
#                                                                     2
# ...
